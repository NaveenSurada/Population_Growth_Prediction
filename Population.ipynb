# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = pd.read_csv('indian population new.csv')

# %%
df.head(15)
# Out:
#     Year    Population % Increase in Population  Population Density  \
# 0   1950  35,70,21,100                    0.00%              108.61
# 1   1951  36,49,22,360                    2.21%              111.01
# 2   1952  37,29,97,188                    2.21%              113.47
# 3   1953  38,12,27,705                    2.21%              115.97
# 4   1954  38,97,31,406                    2.23%              118.56
# 5   1955  39,85,77,992                    2.27%              121.25
# 6   1956  40,76,56,597                    2.28%              124.01
# 7   1957  41,69,35,399                    2.28%              126.83
# 8   1958  42,62,95,763                    2.25%              129.68
# 9   1959  43,59,00,352                    2.25%              132.60
# 10  1960  44,59,54,579                    2.31%              135.66
# 11  1961  45,63,51,876                    2.33%              138.82
# 12  1962  46,70,24,193                    2.34%              142.07
# ...

# %%
df.tail()
# Out:
#     Year      Population % Increase in Population  Population Density  \
# 67  2017  1,35,41,95,680                    1.16%              411.95
# 68  2018  1,36,90,03,306                    1.09%              416.46
# 69  2019  1,38,31,12,050                    1.03%              420.75
# 70  2020  1,39,63,87,127                    0.96%              424.79
# 71  2021  1,40,75,63,842                    0.80%              428.19
#
#    % Increase in Population Density Urban Population  \
# 67                            1.16%     44,97,95,398
# 68                            1.09%     46,03,04,169
# 69                            1.03%     47,10,31,529
# 70                            0.96%     48,19,80,332
# 71                            0.80%     49,31,69,259
#
#    Urban Population % of Total Population % Increase in Urban Population  \
# 67                                   33.6                          2.32%
# 68                                  34.03                          2.31%
# ...

# %%
df.shape
# Out:
# (72, 23)

# %%
df.drop(['% Increase in Population','% Increase in Population Density','Urban Population % of Total Population','% Increase in Urban Population','Rural Population % of Total Population','% Increase in Rural Population','% Increase in Life Expectancy','% Change in Birth Rate','% Change in Death Rate','% Change in Infant Mortality Rate','% Change in Fertility Rate','% Change in Net Migration Rate'], axis=1,inplace= True)

# %%
df.drop(range(0,62), axis=0,inplace= True)

# %%
df
# Out:
#     Year      Population  Population Density Urban Population  \
# 62  2012  1,27,44,87,215              387.71     40,04,16,922
# 63  2013  1,29,11,32,063              392.77     40,99,07,903
# 64  2014  1,30,72,46,509              397.67     41,95,67,353
# 65  2015  1,32,28,66,505              402.42     42,94,28,650
# 66  2016  1,33,86,36,340              407.22     43,95,01,314
# 67  2017  1,35,41,95,680              411.95     44,97,95,398
# 68  2018  1,36,90,03,306              416.46     46,03,04,169
# 69  2019  1,38,31,12,050              420.75     47,10,31,529
# 70  2020  1,39,63,87,127              424.79     48,19,80,332
# 71  2021  1,40,75,63,842              428.19     49,31,69,259
#
#    Rural Population  Life Expectancy  Birth Rate  Death Rate  \
# 62     86,53,63,321            67.32      20.209       7.372
# 63     87,09,34,216            67.77      19.560       7.263
# 64     87,60,33,415            68.07      19.252       7.258
# ...

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index  Year      Population  Population Density Urban Population  \
# 0     62  2012  1,27,44,87,215              387.71     40,04,16,922
# 1     63  2013  1,29,11,32,063              392.77     40,99,07,903
# 2     64  2014  1,30,72,46,509              397.67     41,95,67,353
# 3     65  2015  1,32,28,66,505              402.42     42,94,28,650
# 4     66  2016  1,33,86,36,340              407.22     43,95,01,314
#
#   Rural Population  Life Expectancy  Birth Rate  Death Rate  \
# 0     86,53,63,321            67.32      20.209       7.372
# 1     87,09,34,216            67.77      19.560       7.263
# 2     87,60,33,415            68.07      19.252       7.258
# 3     88,07,23,742            68.37      18.944       7.253
# 4     88,50,15,936            68.67      18.636       7.247
#
#    Infant Mortality Rate  Fertility Rate  Net Migration Rate
# 0                 41.157           2.476              -0.384
# 1                 39.082           2.396              -0.369
# ...

# %%
df.drop(["index"],axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# Year                     0
# Population               0
# Population Density       0
# Urban Population         0
# Rural Population         0
# Life Expectancy          0
# Birth Rate               0
# Death Rate               0
# Infant Mortality Rate    0
# Fertility Rate           0
# Net Migration Rate       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   10 non-null     int64
#  1   Population             10 non-null     object
#  2   Population Density     10 non-null     float64
#  3   Urban Population       10 non-null     object
#  4   Rural Population       10 non-null     object
#  5   Life Expectancy        10 non-null     float64
#  6   Birth Rate             10 non-null     float64
#  7   Death Rate             10 non-null     float64
#  8   Infant Mortality Rate  10 non-null     float64
#  9   Fertility Rate         10 non-null     float64
#  10  Net Migration Rate     10 non-null     float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 1008.0+ bytes

# %%
df["Population"]=df["Population"].str.replace('[\,]',"").astype(int)

# %%
df["Urban Population"]=df["Urban Population"].str.replace('[\,]',"").astype(int)

# %%
df["Rural Population"]=df["Rural Population"].str.replace('[\,]',"").astype(int)

# %%
df.describe()
# Out:
#              Year    Population  Population Density  Urban Population  \
# count    10.00000  1.000000e+01           10.000000      1.000000e+01
# mean   2016.50000  1.344463e+09          408.993000      4.455103e+08
# std       3.02765  4.533181e+07           13.790121      3.119598e+07
# min    2012.00000  1.274487e+09          387.710000      4.004169e+08
# 25%    2014.25000  1.311152e+09          398.857500      4.220327e+08
# 50%    2016.50000  1.346416e+09          409.585000      4.446484e+08
# 75%    2018.75000  1.379585e+09          419.677500      4.683497e+08
# max    2021.00000  1.407564e+09          428.190000      4.931693e+08
#
#        Rural Population  Life Expectancy  Birth Rate  Death Rate  \
# count      1.000000e+01        10.000000   10.000000   10.000000
# mean       8.852940e+08        68.763000   18.572400    7.279800
# std        1.183183e+07         0.877028    0.918949    0.046348
# min        8.653633e+08        67.320000   17.377000    7.237000
# ...

# %%
df.shape
# Out:
# (10, 11)

# %%
df.corr()
# Out:
#                            Year  Population  Population Density  \
# Year                   1.000000    0.998904            0.998909
# Population             0.998904    1.000000            1.000000
# Population Density     0.998909    1.000000            1.000000
# Urban Population       0.999653    0.997373            0.997381
# Rural Population       0.990977    0.995888            0.995876
# Life Expectancy        0.996526    0.998940            0.998935
# Birth Rate            -0.989884   -0.994276           -0.994263
# Death Rate             0.036423   -0.004673           -0.004552
# Infant Mortality Rate -0.996602   -0.999020           -0.999015
# Fertility Rate        -0.982969   -0.988700           -0.988682
# Net Migration Rate     0.236888    0.200411            0.200444
#
#                        Urban Population  Rural Population  Life Expectancy  \
# Year                           0.999653          0.990977         0.996526
# ...

# %%
sns.heatmap(df.corr(), cmap='RdBu', annot= True)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(x='Urban Population', y='Rural Population', data= df)
# Out:
# <AxesSubplot:xlabel='Urban Population', ylabel='Rural Population'>

# %%
df.columns
# Out:
# Index(['Year', 'Population', 'Population Density', 'Urban Population',
#        'Rural Population', 'Life Expectancy', 'Birth Rate', 'Death Rate',
#        'Infant Mortality Rate', 'Fertility Rate', 'Net Migration Rate'],
#       dtype='object')

# %%
feature=['Population', 'Population Density', 'Urban Population',
       'Rural Population', 'Life Expectancy', 'Birth Rate', 'Death Rate',
       'Infant Mortality Rate', 'Fertility Rate', 'Net Migration Rate']

# %%
list(enumerate(feature))
# Out:
# [(0, 'Population'),
#  (1, 'Population Density'),
#  (2, 'Urban Population'),
#  (3, 'Rural Population'),
#  (4, 'Life Expectancy'),
#  (5, 'Birth Rate'),
#  (6, 'Death Rate'),
#  (7, 'Infant Mortality Rate'),
#  (8, 'Fertility Rate'),
#  (9, 'Net Migration Rate')]

# %%
plt.figure(figsize=(15,20))
for i in enumerate(feature):
    plt.subplot(4,3,i[0]+1)
    sns.scatterplot(data=df,x='Year',y=i[1],marker="*")
    plt.xticks(rotation=45)

# %%
x=df.drop('Population',axis=1)
x.skew()
# Out:
# Year                     0.000000
# Population Density      -0.135978
# Urban Population         0.082536
# Rural Population        -0.414458
# Life Expectancy         -0.251044
# Birth Rate               0.434624
# Death Rate               1.214897
# Infant Mortality Rate    0.248323
# Fertility Rate           0.575494
# Net Migration Rate       0.509554
# dtype: float64

# %%
y=df['Population']

# %%
y.shape
# Out:
# (10,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()

# %%
sc.fit_transform(x)
# Out:
# array([[-1.5666989 , -1.62683499, -1.52367648, -1.77561645, -1.73432865,
#          1.87728272,  2.09688473,  1.7284567 ,  1.97407769, -0.4713952 ],
#        [-1.21854359, -1.24005751, -1.20298216, -1.27930802, -1.19347772,
#          1.13283906, -0.38207878,  1.19809061,  1.08535391,  0.86274215],
#        [-0.87038828, -0.86551015, -0.87659539, -0.82502277, -0.83291043,
#          0.77954377, -0.4957927 ,  0.83616368,  0.74097345,  0.4180297 ],
#        [-0.52223297, -0.50242853, -0.54338832, -0.40716374, -0.47234315,
#          0.42624848, -0.60950662,  0.47398115,  0.39659299, -0.11562524],
#        [-0.17407766, -0.13552499, -0.2030393 , -0.02477419, -0.11177586,
#          0.07295318, -0.74596333,  0.11205421,  0.04110347, -0.56033769],
#        [ 0.17407766,  0.22602787,  0.14479136,  0.3195965 ,  0.24879143,
#         -0.28034211, -0.85967725, -0.25012832, -0.30327699, -1.09399263],
#        [ 0.52223297,  0.57076431,  0.49987616,  0.62755522,  0.60935871,
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.svm import LinearSVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, RandomForestRegressor

# %%
models = {
    "                     Linear Regression" : LinearRegression(),
    "                 L2 (Ridge) Regression" : Ridge(),
    "Support Vector Machine (Linear Kernel)" : LinearSVR(),
    "                         Decision Tree" : DecisionTreeRegressor(),
    "                        Neural Network" : MLPRegressor(),
    "                         Random Forest" : RandomForestRegressor(),
    "                     Gradient Boosting" : GradientBoostingRegressor(),
    "                              AdaBoost" : AdaBoostRegressor()
}

# %%
for name,model in models.items():
    model.fit(x_train,y_train)
    print('model trained with. {}'.format(name))
# Out:
# model trained with.                      Linear Regression
# model trained with.                  L2 (Ridge) Regression
# model trained with. Support Vector Machine (Linear Kernel)
# model trained with.                          Decision Tree
# model trained with.                         Neural Network
# model trained with.                          Random Forest
# model trained with.                      Gradient Boosting
# model trained with.                               AdaBoost

# %%
from sklearn.metrics import r2_score

# %%
for name,model in models.items():
    y_pred=model.predict(x_test)
    score= r2_score(y_test,y_pred)
    print(score)
# Out:
# 0.9999999501903306
# 0.9997890468836768
# 0.9977857708412183
# 0.8481541720435026
# 0.9120935046628916
# 0.9954676690470752
# 0.9619051021156171
# 0.8391978155996861

# %%
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.9999999501903306

# %%
import pickle

# %%
file=open('population.pkl','wb')

# %%
pickle.dump(model,file)
